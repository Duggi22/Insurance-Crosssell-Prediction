# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df= pd.read_csv ("C://Users//satis//Desktop//Submission//Dataset.csv")

# %%
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
df.isna().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
df.nunique()
# Out:
# id                      381109
# Gender                       2
# Age                         66
# Driving_License              2
# Region_Code                 53
# Previously_Insured           2
# Vehicle_Age                  3
# Vehicle_Damage               2
# Annual_Premium           48838
# Policy_Sales_Channel       155
# Vintage                    290
# Response                     2
# dtype: int64

# %%
df["Response"].value_counts(normalize=True)
# Out:
# 0    0.877437
# 1    0.122563
# Name: Response, dtype: float64

# %%
df["Policy_Sales_Channel"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          26.0
# 1          26.0
# 2          26.0
# 3         152.0
# 4         152.0
#           ...
# 381104     26.0
# 381105    152.0
# 381106    160.0
# 381107    124.0
# 381108     26.0
# Name: Policy_Sales_Channel, Length: 381109, dtype: float64>

# %%
sns.countplot(data=df, x="Response", hue="Vehicle_Age")
# Out:
# <AxesSubplot:xlabel='Response', ylabel='count'>

# %%
plt.figure(figsize=(4,4))
sns.countplot(x = 'Response', palette = 'Set2', data = df)
plt.show()

# %%
plt.figure(figsize = (20,25))

plt.subplot(4,2,1)
plt.gca().set_title('Variable Gender')
sns.countplot(x = 'Gender', palette = 'Set2', data = df)

plt.subplot(4,2,2)
plt.gca().set_title('Variable Driving_License')
sns.countplot(x = 'Driving_License', palette = 'Set2', data = df)

plt.subplot(4,2,3)
plt.gca().set_title('Variable Previously_Insured')
sns.countplot(x = 'Previously_Insured', palette = 'Set2', data = df)

plt.subplot(4,2,4)
plt.gca().set_title('Variable Vehicle_Age')
sns.countplot(x = 'Vehicle_Age', palette = 'Set2', data = df)

plt.subplot(4,2,5)
plt.gca().set_title('Variable Vehicle_Damage')
sns.countplot(x = 'Vehicle_Damage', palette = 'Set2', data = df)

plt.subplot(4,2,6)
plt.gca().set_title('Variable Previously_Insured')
sns.countplot(x = 'Previously_Insured', palette = 'Set2', data = df)

plt.subplot(4,2,7)
plt.gca().set_title('Variable Response')
sns.countplot(x = 'Response', palette = 'Set2', data = df)
# Out:
# <AxesSubplot:title={'center':'Variable Response'}, xlabel='Response', ylabel='count'>

# %% [markdown]
# # we can see that the data is well divided between men and women, all the data in our data set have a driving license, looking at whether the customer has had insurance before, we have practically the same values, when we look at age of the car we practically only have new cars, looking at our target variable practically most of our customers would not like insurance.

# %%
df.drop(df.columns[0] , inplace = True , axis = 1)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot = True,cmap = 'YlOrBr')
plt.show()

# %%
sns.boxplot(x= df["Annual_Premium"])
# Out:
# <AxesSubplot:xlabel='Annual_Premium'>

# %%
sns.boxplot(x= df["Vintage"])
# Out:
# <AxesSubplot:xlabel='Vintage'>

# %%
sns.boxplot(x= df["Policy_Sales_Channel"])
# Out:
# <AxesSubplot:xlabel='Policy_Sales_Channel'>

# %%
plt.figure(figsize = (20, 25))
plt.suptitle("Analysis Of Variable Vehicle_Damage",fontweight="bold", fontsize=20)

plt.subplot(5,2,1)
sns.countplot(x = 'Vehicle_Damage', hue = 'Response', palette = 'Set2', data = df)

plt.subplot(5,2,2)
sns.countplot(x = 'Vehicle_Damage', hue = 'Vehicle_Age', palette = 'Set2', data = df)

plt.subplot(5,2,3)
sns.countplot(x = 'Vehicle_Damage', hue = 'Previously_Insured', palette = 'Set2', data = df)

plt.subplot(5,2,4)
sns.countplot(x = 'Vehicle_Damage', hue = 'Driving_License', palette = 'Set2', data = df)

plt.subplot(5,2,5)
sns.kdeplot(x='Age', hue='Vehicle_Damage', palette = 'Set2', shade=True, data=df)

plt.subplot(5,2,6)
sns.kdeplot(x='Region_Code', hue='Vehicle_Damage', palette = 'Set2', shade=True, data=df)

plt.subplot(5,2,7)
sns.kdeplot(x='Annual_Premium', hue='Vehicle_Damage', palette = 'Set2', shade=True, data=df)

plt.subplot(5,2,8)
sns.kdeplot(x='Policy_Sales_Channel', hue='Vehicle_Damage', palette = 'Set2', shade=True, data=df)

plt.subplot(5,2,9)
sns.kdeplot(x='Vintage', hue='Vehicle_Damage', palette = 'Set2', shade=True, data=df)
# Out:
# <AxesSubplot:xlabel='Vintage', ylabel='Density'>

# %% [markdown]
# # after verifying that practically all people who want insurance had their car previously damaged, we can see that practically all cars older than 2 years have already been damaged, and when we look at the undamaged cars, we have a large volume of new cars, which makes a lot of sense, a very interesting thing to look at is that when we compare the variable Previously Insured and Vehicle Damage we can see that most of the cars that have already been damaged were not Previously Insured and most of non-damaged cars were Previously Insured, another interesting thing is when we look at the age variable, the younger ones did not have a damaged vehicle and between 40-50 years old did, when we look at the other continuous variables we had practically the same distribution.

# %%
plt.figure(figsize = (20, 25))
plt.suptitle("Analysis Of Variable Response",fontweight="bold", fontsize=20)

plt.subplot(5,2,1)
sns.countplot(x = 'Response', hue = 'Gender', palette = 'Set2', data = df)

plt.subplot(5,2,2)
sns.countplot(x = 'Response', hue = 'Previously_Insured', palette = 'Set2', data = df)

plt.subplot(5,2,3)
sns.countplot(x = 'Response', hue = 'Vehicle_Age', palette = 'Set2', data = df)

plt.subplot(5,2,4)
sns.countplot(x = 'Response', hue = 'Vehicle_Damage', palette = 'Set2', data = df)

plt.subplot(5,2,5)
sns.countplot(x = 'Response', hue = 'Driving_License', palette = 'Set2', data = df)

plt.subplot(5,2,6)
sns.kdeplot(x='Age', hue='Response', palette = 'Set2', shade=True, data=df)

plt.subplot(5,2,7)
sns.kdeplot(x='Region_Code', hue='Response', palette = 'Set2', shade=True, data=df)

plt.subplot(5,2,8)
sns.kdeplot(x='Annual_Premium', hue='Response', palette = 'Set2', shade=True, data=df)

plt.subplot(5,2,9)
sns.kdeplot(x='Policy_Sales_Channel', hue='Response', palette = 'Set2', shade=True, data=df)

plt.subplot(5,2,10)
sns.kdeplot(x='Vintage', hue='Response', palette = 'Set2', shade=True, data=df)
# Out:
# <AxesSubplot:xlabel='Vintage', ylabel='Density'>

# %%
from sklearn import preprocessing
le= preprocessing.LabelEncoder()
df["Gender"]= le.fit_transform(df["Gender"])
df["Vehicle_Age"]= le.fit_transform(df["Vehicle_Age"])
df["Vehicle_Damage"]= le.fit_transform(df["Vehicle_Damage"])

# %%
X= df.drop(["Response"], axis =1 )
y= df["Response"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Gender                381109 non-null  int32
#  1   Age                   381109 non-null  int64
#  2   Driving_License       381109 non-null  int64
#  3   Region_Code           381109 non-null  float64
#  4   Previously_Insured    381109 non-null  int64
#  5   Vehicle_Age           381109 non-null  int32
#  6   Vehicle_Damage        381109 non-null  int32
#  7   Annual_Premium        381109 non-null  float64
#  8   Policy_Sales_Channel  381109 non-null  float64
#  9   Vintage               381109 non-null  int64
#  10  Response              381109 non-null  int64
# dtypes: float64(3), int32(3), int64(5)
# memory usage: 27.6 MB

# %%
df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  Vehicle_Age  \
# 0       1   44                1         28.0                   0            2
# 1       1   76                1          3.0                   0            0
# 2       1   47                1         28.0                   0            2
# 3       1   21                1         11.0                   1            1
# 4       0   29                1         41.0                   1            1
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0               1         40454.0                  26.0      217         1
# 1               0         33536.0                  26.0      183         0
# 2               1         38294.0                  26.0       27         1
# 3               0         28619.0                 152.0      203         0
# 4               0         27496.0                 152.0       39         0

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler(random_state=0)
X, y = ros.fit_resample(X, y)

# %%
y.value_counts()
# Out:
# 1    334399
# 0    334399
# Name: Response, dtype: int64

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.naive_bayes import GaussianNB
naive_bayes = GaussianNB()
naive_bayes.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_nav = naive_bayes.predict(X_test)

# %%
print(confusion_matrix(y_test,y_nav))
print(classification_report(y_test,y_nav))
# Out:
# [[65168 35160]
#  [ 9199 91113]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.65      0.75    100328
#            1       0.72      0.91      0.80    100312
#
#     accuracy                           0.78    200640
#    macro avg       0.80      0.78      0.78    200640
# weighted avg       0.80      0.78      0.78    200640

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel= LogisticRegression()
logmodel.fit(X_train,y_train)
prediction=logmodel.predict(X_test)
print(confusion_matrix(y_test,prediction))
print(classification_report(y_test,prediction))
# Out:
# C:\Users\satis\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [[59208 41120]
#  [ 3898 96414]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.59      0.72    100328
#            1       0.70      0.96      0.81    100312
#
#     accuracy                           0.78    200640
#    macro avg       0.82      0.78      0.77    200640
# weighted avg       0.82      0.78      0.77    200640

# %%
DT=DecisionTreeClassifier(criterion='entropy',min_samples_leaf=15)
DT.fit(X_train, y_train)
y_dtpred= DT.predict(X_test) 
print(confusion_matrix(y_test,y_dtpred))
print(classification_report(y_test,y_dtpred))
# Out:
# [[78473 21855]
#  [12530 87782]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82    100328
#            1       0.80      0.88      0.84    100312
#
#     accuracy                           0.83    200640
#    macro avg       0.83      0.83      0.83    200640
# weighted avg       0.83      0.83      0.83    200640

# %%
from xgboost import XGBClassifier
model=XGBClassifier()
eval_set=[(X_test,y_test)]
model.fit(X_train,y_train,early_stopping_rounds=15,eval_metric="logloss",eval_set=eval_set)
# Out:
# C:\Users\satis\anaconda3\lib\site-packages\xgboost\sklearn.py:861: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\satis\anaconda3\lib\site-packages\xgboost\sklearn.py:861: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-logloss:0.58446
# [1]	validation_0-logloss:0.52624
# [2]	validation_0-logloss:0.49159
# [3]	validation_0-logloss:0.46979
# [4]	validation_0-logloss:0.45566
# [5]	validation_0-logloss:0.44605
# [6]	validation_0-logloss:0.43853
# [7]	validation_0-logloss:0.43365
# [8]	validation_0-logloss:0.42983
# [9]	validation_0-logloss:0.42724
# [10]	validation_0-logloss:0.42513
# [11]	validation_0-logloss:0.42374
# [12]	validation_0-logloss:0.42242
# [13]	validation_0-logloss:0.42136
# [14]	validation_0-logloss:0.42042
# [15]	validation_0-logloss:0.41969
# [16]	validation_0-logloss:0.41919
# [17]	validation_0-logloss:0.41881
# [18]	validation_0-logloss:0.41846
# [19]	validation_0-logloss:0.41796
# [20]	validation_0-logloss:0.41757
# [21]	validation_0-logloss:0.41692
# [22]	validation_0-logloss:0.41656
# [23]	validation_0-logloss:0.41622
# [24]	validation_0-logloss:0.41594
# [25]	validation_0-logloss:0.41550
# [26]	validation_0-logloss:0.41495
# [27]	validation_0-logloss:0.41464
# [28]	validation_0-logloss:0.41452
# [29]	validation_0-logloss:0.41430
# [30]	validation_0-logloss:0.41405
# [31]	validation_0-logloss:0.41378
# [32]	validation_0-logloss:0.41362
# [33]	validation_0-logloss:0.41318
# [34]	validation_0-logloss:0.41293
# [35]	validation_0-logloss:0.41264
# [36]	validation_0-logloss:0.41232
# [37]	validation_0-logloss:0.41219
# [38]	validation_0-logloss:0.41218
# [39]	validation_0-logloss:0.41202
# [40]	validation_0-logloss:0.41188
# [41]	validation_0-logloss:0.41175
# [42]	validation_0-logloss:0.41154
# [43]	validation_0-logloss:0.41136
# [44]	validation_0-logloss:0.41110
# [45]	validation_0-logloss:0.41097
# [46]	validation_0-logloss:0.41079
# [47]	validation_0-logloss:0.41057
# [48]	validation_0-logloss:0.41044
# [49]	validation_0-logloss:0.41011
# [50]	validation_0-logloss:0.40984
# [51]	validation_0-logloss:0.40968
# [52]	validation_0-logloss:0.40951
# [53]	validation_0-logloss:0.40936
# [54]	validation_0-logloss:0.40927
# [55]	validation_0-logloss:0.40920
# [56]	validation_0-logloss:0.40909
# [57]	validation_0-logloss:0.40887
# [58]	validation_0-logloss:0.40870
# [59]	validation_0-logloss:0.40854
# [60]	validation_0-logloss:0.40838
# [61]	validation_0-logloss:0.40806
# [62]	validation_0-logloss:0.40802
# [63]	validation_0-logloss:0.40797
# [64]	validation_0-logloss:0.40794
# [65]	validation_0-logloss:0.40792
# [66]	validation_0-logloss:0.40789
# [67]	validation_0-logloss:0.40770
# [68]	validation_0-logloss:0.40761
# [69]	validation_0-logloss:0.40751
# [70]	validation_0-logloss:0.40719
# [71]	validation_0-logloss:0.40696
# [72]	validation_0-logloss:0.40671
# [73]	validation_0-logloss:0.40648
# [74]	validation_0-logloss:0.40629
# [75]	validation_0-logloss:0.40610
# [76]	validation_0-logloss:0.40586
# [77]	validation_0-logloss:0.40562
# [78]	validation_0-logloss:0.40552
# [79]	validation_0-logloss:0.40529
# [80]	validation_0-logloss:0.40517
# [81]	validation_0-logloss:0.40507
# [82]	validation_0-logloss:0.40487
# [83]	validation_0-logloss:0.40473
# [84]	validation_0-logloss:0.40460
# [85]	validation_0-logloss:0.40442
# [86]	validation_0-logloss:0.40436
# [87]	validation_0-logloss:0.40426
# [88]	validation_0-logloss:0.40406
# [89]	validation_0-logloss:0.40389
# [90]	validation_0-logloss:0.40377
# [91]	validation_0-logloss:0.40367
# [92]	validation_0-logloss:0.40357
# [93]	validation_0-logloss:0.40340
# [94]	validation_0-logloss:0.40320
# [95]	validation_0-logloss:0.40298
# [96]	validation_0-logloss:0.40286
# [97]	validation_0-logloss:0.40271
# [98]	validation_0-logloss:0.40252
# [99]	validation_0-logloss:0.40242
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
predictions=model.predict(X_test)
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[68797 31531]
#  [ 6156 94156]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.69      0.78    100328
#            1       0.75      0.94      0.83    100312
#
#     accuracy                           0.81    200640
#    macro avg       0.83      0.81      0.81    200640
# weighted avg       0.83      0.81      0.81    200640

# %%
grid = { 
    'n_estimators': [100],
    'max_features': ['log2' ],
    'criterion' :['gini'],
    'random_state' : [18]
}
rf_cv = GridSearchCV(estimator=RandomForestClassifier(), param_grid=grid, cv=5 )
rf_cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini'], 'max_features': ['log2'],
#                          'n_estimators': [100], 'random_state': [18]})

# %%
RF_pred=rf_cv.predict(X_test)
print(confusion_matrix(y_test,RF_pred))
print(classification_report(y_test,RF_pred))
# Out:
# [[88563 11765]
#  [  323 99989]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94    100328
#            1       0.89      1.00      0.94    100312
#
#     accuracy                           0.94    200640
#    macro avg       0.95      0.94      0.94    200640
# weighted avg       0.95      0.94      0.94    200640

# %%
from sklearn.ensemble import AdaBoostClassifier
clf2=AdaBoostClassifier(random_state=96,n_estimators=100)
clf2.fit(X_train,y_train)
clf2pred=clf2.predict(X_test)
print(confusion_matrix(y_test,clf2pred))
print(classification_report(y_test,clf2pred))
# Out:
# [[66351 33977]
#  [ 6679 93633]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.66      0.77    100328
#            1       0.73      0.93      0.82    100312
#
#     accuracy                           0.80    200640
#    macro avg       0.82      0.80      0.79    200640
# weighted avg       0.82      0.80      0.79    200640

# %% [markdown]
# # We can see that Random Forest Model has out performed well amoung all the other algorithms.

# %%
import pickle

# %%
filename= 'trained_model.sav'
pickle.dump(rf_cv, open(filename , 'wb'))

# %%
pickle.dump(df,open('df.pkl','wb'))

# %%
df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  Vehicle_Age  \
# 0       1   44                1         28.0                   0            2
# 1       1   76                1          3.0                   0            0
# 2       1   47                1         28.0                   0            2
# 3       1   21                1         11.0                   1            1
# 4       0   29                1         41.0                   1            1
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0               1         40454.0                  26.0      217         1
# 1               0         33536.0                  26.0      183         0
# 2               1         38294.0                  26.0       27         1
# 3               0         28619.0                 152.0      203         0
# 4               0         27496.0                 152.0       39         0
